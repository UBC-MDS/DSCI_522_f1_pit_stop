# %% [markdown]
# **This Dataset was found at: https://www.kaggle.com/rohanrao/formula-1-world-championship-1950-2020**

# %% [markdown]
# ## Data Wrangling - Cleaning the data

# %%
import pandas as pd
results = pd.read_csv("results.csv")
results.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452         218.300         1
# 1         41    3       1:27.739         217.586         1
# 2         41    5       1:28.090         216.719         1
# 3         58    7       1:28.603         215.464         1
# 4         43    1       1:27.418         218.385         1

# %%
results['fastestLapTime']
# Out:
# 0        1:27.452
# 1        1:27.739
# 2        1:28.090
# 3        1:28.603
# 4        1:27.418
#            ...
# 25135    1:08.520
# 25136    1:08.420
# 25137    1:09.394
# 25138    1:09.757
# 25139          \N
# Name: fastestLapTime, Length: 25140, dtype: object

# %%
results.describe()
# Out:
#            resultId        raceId      driverId  constructorId          grid  \
# count  25140.000000  25140.000000  25140.000000   25140.000000  25140.000000
# mean   12571.218337    516.215712    249.500438      47.323230     11.211734
# std     7258.469117    289.167348    256.875639      58.208313      7.275871
# min        1.000000      1.000000      1.000000       1.000000      0.000000
# 25%     6285.750000    286.000000     56.000000       6.000000      5.000000
# 50%    12570.500000    501.000000    158.000000      25.000000     11.000000
# 75%    18855.250000    759.000000    347.000000      57.000000     17.000000
# max    25145.000000   1060.000000    854.000000     214.000000     34.000000
#
#        positionOrder        points          laps      statusId
# count   25140.000000  25140.000000  25140.000000  25140.000000
# mean       12.942164      1.789521     45.804455     17.757399
# std         7.749181      4.018738     30.036217     26.122051
# min         1.000000      0.000000      0.000000      1.000000
# 25%         6.000000      0.000000     21.000000      1.000000
# 50%        12.000000      0.000000     52.000000     11.000000
# 75%        19.000000      2.000000     66.000000     15.000000
# max        39.000000     50.000000    200.000000    139.000000

# %%
results.count()
# Out:
# resultId           25140
# raceId             25140
# driverId           25140
# constructorId      25140
# number             25140
# grid               25140
# position           25140
# positionText       25140
# positionOrder      25140
# points             25140
# laps               25140
# time               25140
# milliseconds       25140
# fastestLap         25140
# rank               25140
# fastestLapTime     25140
# fastestLapSpeed    25140
# statusId           25140
# dtype: int64

# %%
# We can check how many null values we have by using the following: 
results.isnull().sum()
# Out:
# resultId           0
# raceId             0
# driverId           0
# constructorId      0
# number             0
# grid               0
# position           0
# positionText       0
# positionOrder      0
# points             0
# laps               0
# time               0
# milliseconds       0
# fastestLap         0
# rank               0
# fastestLapTime     0
# fastestLapSpeed    0
# statusId           0
# dtype: int64

# %%
results.dropna(inplace=True) # Drop all data where there exists a NaN in the row. 
results.isnull().sum()
# Out:
# resultId           0
# raceId             0
# driverId           0
# constructorId      0
# number             0
# grid               0
# position           0
# positionText       0
# positionOrder      0
# points             0
# laps               0
# time               0
# milliseconds       0
# fastestLap         0
# rank               0
# fastestLapTime     0
# fastestLapSpeed    0
# statusId           0
# dtype: int64

# %%
results['fastestLapTime']
# Out:
# 0        1:27.452
# 1        1:27.739
# 2        1:28.090
# 3        1:28.603
# 4        1:27.418
#            ...
# 25135    1:08.520
# 25136    1:08.420
# 25137    1:09.394
# 25138    1:09.757
# 25139          \N
# Name: fastestLapTime, Length: 25140, dtype: object

# %%
results.count()
# Out:
# resultId           25140
# raceId             25140
# driverId           25140
# constructorId      25140
# number             25140
# grid               25140
# position           25140
# positionText       25140
# positionOrder      25140
# points             25140
# laps               25140
# time               25140
# milliseconds       25140
# fastestLap         25140
# rank               25140
# fastestLapTime     25140
# fastestLapSpeed    25140
# statusId           25140
# dtype: int64

# %% [markdown]
# Our Results are all cleaned and ready to be used!

# %%
# Our Data Types
results.dtypes
# Out:
# resultId             int64
# raceId               int64
# driverId             int64
# constructorId        int64
# number              object
# grid                 int64
# position            object
# positionText        object
# positionOrder        int64
# points             float64
# laps                 int64
# time                object
# milliseconds        object
# fastestLap          object
# rank                object
# fastestLapTime      object
# fastestLapSpeed     object
# statusId             int64
# dtype: object

# %%
# Reading the Drivers csv File
drivers = pd.read_csv("drivers.csv", encoding = "ISO-8859-1")
drivers.head()
# Out:
#    driverId   driverRef number code  forename     surname         dob  \
# 0         1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1         2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4         5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
#Merging the Drivers CSV file and saving it to merge
merge = pd.merge(results, drivers, how="inner", on="driverId")
merge
# Out:
#        resultId  raceId  driverId  constructorId number_x  grid position  \
# 0             1      18         1              1       22     1        1
# 1            27      19         1              1       22     9        5
# 2            57      20         1              1       22     3       13
# 3            69      21         1              1       22     5        3
# 4            90      22         1              1       22     3        2
# ...         ...     ...       ...            ...      ...   ...      ...
# 25135     25062    1056       853            210        9    19       17
# 25136     25079    1057       853            210        9    18       14
# 25137     25105    1059       853            210        9    18       20
# 25138     25123    1058       853            210        9    20       18
# 25139     25144    1060       853            210        9    20       19
#
#       positionText  positionOrder  points  ...  fastestLapSpeed statusId  \
# 0                1              1    10.0  ...          218.300        1
# 1                5              5     4.0  ...          209.033        1
# 2               13             13     0.0  ...          203.969       11
# 3                3              3     6.0  ...          204.323        1
# 4                2              2     8.0  ...          222.085        1
# ...            ...            ...     ...  ...              ...      ...
# 25135           17             17     0.0  ...          156.287       13
# 25136           14             14     0.0  ...          200.569        1
# 25137           20             20     0.0  ...          211.758       11
# 25138           18             18     0.0  ...          219.092       13
# 25139           19             19     0.0  ...          222.842       12
#
#       driverRef number_y code forename   surname         dob nationality  \
# 0      hamilton       44  HAM    Lewis  Hamilton  1985-01-07     British
# 1      hamilton       44  HAM    Lewis  Hamilton  1985-01-07     British
# 2      hamilton       44  HAM    Lewis  Hamilton  1985-01-07     British
# 3      hamilton       44  HAM    Lewis  Hamilton  1985-01-07     British
# 4      hamilton       44  HAM    Lewis  Hamilton  1985-01-07     British
# ...         ...      ...  ...      ...       ...         ...         ...
# 25135   mazepin        9  MAZ   Nikita   Mazepin  1999-03-02     Russian
# 25136   mazepin        9  MAZ   Nikita   Mazepin  1999-03-02     Russian
# 25137   mazepin        9  MAZ   Nikita   Mazepin  1999-03-02     Russian
# 25138   mazepin        9  MAZ   Nikita   Mazepin  1999-03-02     Russian
# 25139   mazepin        9  MAZ   Nikita   Mazepin  1999-03-02     Russian
#
#                                                url
# 0      http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      http://en.wikipedia.org/wiki/Lewis_Hamilton
# 2      http://en.wikipedia.org/wiki/Lewis_Hamilton
# 3      http://en.wikipedia.org/wiki/Lewis_Hamilton
# 4      http://en.wikipedia.org/wiki/Lewis_Hamilton
# ...                                            ...
# 25135  http://en.wikipedia.org/wiki/Nikita_Mazepin
# 25136  http://en.wikipedia.org/wiki/Nikita_Mazepin
# 25137  http://en.wikipedia.org/wiki/Nikita_Mazepin
# 25138  http://en.wikipedia.org/wiki/Nikita_Mazepin
# 25139  http://en.wikipedia.org/wiki/Nikita_Mazepin
#
# [25140 rows x 26 columns]

# %%
# reading the status csv file
status = pd.read_csv("status.csv", encoding = "ISO-8859-1")
status.head()
# Out:
#    statusId        status
# 0         1      Finished
# 1         2  Disqualified
# 2         3      Accident
# 3         4     Collision
# 4         5        Engine

# %%
# merging merge and status, saving it to d1
d1 = pd.merge(merge, status, how="inner", on='statusId')
d1.head()
# Out:
#    resultId  raceId  driverId  constructorId number_x  grid position  \
# 0         1      18         1              1       22     1        1
# 1        27      19         1              1       22     9        5
# 2        69      21         1              1       22     5        3
# 3        90      22         1              1       22     3        2
# 4       109      23         1              1       22     3        1
#
#   positionText  positionOrder  points  ...  statusId driverRef number_y code  \
# 0            1              1    10.0  ...         1  hamilton       44  HAM
# 1            5              5     4.0  ...         1  hamilton       44  HAM
# 2            3              3     6.0  ...         1  hamilton       44  HAM
# 3            2              2     8.0  ...         1  hamilton       44  HAM
# 4            1              1    10.0  ...         1  hamilton       44  HAM
#
#   forename   surname         dob  nationality  \
# 0    Lewis  Hamilton  1985-01-07      British
# 1    Lewis  Hamilton  1985-01-07      British
# 2    Lewis  Hamilton  1985-01-07      British
# 3    Lewis  Hamilton  1985-01-07      British
# 4    Lewis  Hamilton  1985-01-07      British
#
#                                            url    status
# 0  http://en.wikipedia.org/wiki/Lewis_Hamilton  Finished
# 1  http://en.wikipedia.org/wiki/Lewis_Hamilton  Finished
# 2  http://en.wikipedia.org/wiki/Lewis_Hamilton  Finished
# 3  http://en.wikipedia.org/wiki/Lewis_Hamilton  Finished
# 4  http://en.wikipedia.org/wiki/Lewis_Hamilton  Finished
#
# [5 rows x 27 columns]

# %%
# droping columns: 'driverId, statusId, driverRef' and saving it to data.
data = d1.drop(['driverId', 'statusId', 'driverRef'], axis = 1)
data.head()
# Out:
#    resultId  raceId  constructorId number_x  grid position positionText  \
# 0         1      18              1       22     1        1            1
# 1        27      19              1       22     9        5            5
# 2        69      21              1       22     5        3            3
# 3        90      22              1       22     3        2            2
# 4       109      23              1       22     3        1            1
#
#    positionOrder  points  laps  ... fastestLapTime fastestLapSpeed number_y  \
# 0              1    10.0    58  ...       1:27.452         218.300       44
# 1              5     4.0    56  ...       1:35.462         209.033       44
# 2              3     6.0    66  ...       1:22.017         204.323       44
# 3              2     8.0    58  ...       1:26.529         222.085       44
# 4              1    10.0    76  ...       1:18.510         153.152       44
#
#   code forename   surname         dob nationality  \
# 0  HAM    Lewis  Hamilton  1985-01-07     British
# 1  HAM    Lewis  Hamilton  1985-01-07     British
# 2  HAM    Lewis  Hamilton  1985-01-07     British
# 3  HAM    Lewis  Hamilton  1985-01-07     British
# 4  HAM    Lewis  Hamilton  1985-01-07     British
#
#                                            url    status
# 0  http://en.wikipedia.org/wiki/Lewis_Hamilton  Finished
# 1  http://en.wikipedia.org/wiki/Lewis_Hamilton  Finished
# 2  http://en.wikipedia.org/wiki/Lewis_Hamilton  Finished
# 3  http://en.wikipedia.org/wiki/Lewis_Hamilton  Finished
# 4  http://en.wikipedia.org/wiki/Lewis_Hamilton  Finished
#
# [5 rows x 24 columns]

# %%
# reading races csv, droping columns: 'round, circuitId, date, time, url'
races = pd.read_csv("races.csv", encoding = "ISO-8859-1")
races = races.drop(['round', 'circuitId', 'date', 'time', 'url'], axis = 1)
races.head()
# Out:
#    raceId  year                   name
# 0       1  2009  Australian Grand Prix
# 1       2  2009   Malaysian Grand Prix
# 2       3  2009     Chinese Grand Prix
# 3       4  2009     Bahrain Grand Prix
# 4       5  2009     Spanish Grand Prix

# %%
# merging data and races, saving it to cleanedData
cleanedData = pd.merge(data, races, how='inner', on='raceId')
cleanedData.head()
# Out:
#    resultId  raceId  constructorId number_x  grid position positionText  \
# 0         1      18              1       22     1        1            1
# 1         2      18              2        3     5        2            2
# 2         3      18              3        7     7        3            3
# 3         4      18              4        5    11        4            4
# 4         5      18              1       23     3        5            5
#
#    positionOrder  points  laps  ... number_y code  forename     surname  \
# 0              1    10.0    58  ...       44  HAM     Lewis    Hamilton
# 1              2     8.0    58  ...       \N  HEI      Nick    Heidfeld
# 2              3     6.0    58  ...        6  ROS      Nico     Rosberg
# 3              4     5.0    58  ...       14  ALO  Fernando      Alonso
# 4              5     4.0    58  ...       \N  KOV    Heikki  Kovalainen
#
#           dob nationality                                             url  \
# 0  1985-01-07     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1  1977-05-10      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2  1985-06-27      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3  1981-07-29     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4  1981-10-19     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen
#
#      status  year                   name
# 0  Finished  2008  Australian Grand Prix
# 1  Finished  2008  Australian Grand Prix
# 2  Finished  2008  Australian Grand Prix
# 3  Finished  2008  Australian Grand Prix
# 4  Finished  2008  Australian Grand Prix
#
# [5 rows x 26 columns]

# %%
# The chart below signifies a 2014 average lap time versus a 2013 indicator time. 
Initial = [10,10,10,10, 10, 10, 10, 10, 10]
SpeedIn2014 = [12.29, 12.07, 11.78, 10.92, 12.71, 11.12, 9.79, 9.82, 10.77]
index = ['Vettel', 'Alonso', 'Rosberg', 'Massa', 'Ricciardo', 'Button', 'Bottas', 'Hamilton', 'Vergne']
df = pd.DataFrame({'2013 Indicator': Initial, '2014 Avg Lap Time': SpeedIn2014}, index=index)
df.plot.bar(rot=0, figsize=(15,5), title = '2013 Indicator against 2014 Average Lap Time')
# Out:
# <AxesSubplot:title={'center':'2013 Indicator against 2014 Average Lap Time'}>

# %%
results = pd.read_csv("results.csv")

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
#      |████████████████████████████████| 292 kB 4.6 MB/s eta 0:00:01
# Requirement already satisfied: matplotlib>=2.2 in /Users/floraouedraogo/opt/miniconda3/lib/python3.9/site-packages (from seaborn) (3.4.3)
# Requirement already satisfied: scipy>=1.0 in /Users/floraouedraogo/opt/miniconda3/lib/python3.9/site-packages (from seaborn) (1.7.1)
# Requirement already satisfied: numpy>=1.15 in /Users/floraouedraogo/opt/miniconda3/lib/python3.9/site-packages (from seaborn) (1.21.2)
# Requirement already satisfied: pandas>=0.23 in /Users/floraouedraogo/opt/miniconda3/lib/python3.9/site-packages (from seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/floraouedraogo/opt/miniconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/floraouedraogo/opt/miniconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (8.3.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/floraouedraogo/opt/miniconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/floraouedraogo/opt/miniconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/floraouedraogo/opt/miniconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: six in /Users/floraouedraogo/opt/miniconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/floraouedraogo/opt/miniconda3/lib/python3.9/site-packages (from pandas>=0.23->seaborn) (2021.1)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.11.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

data = results

df = pd.DataFrame(data,columns=['raceId','driverId','lap','position','time', 'milliseconds'])

corrMatrix = df.corr()
plt.subplots(figsize=(20,15))
sn.heatmap(corrMatrix, annot=True)
plt.show()
